# %%
liked_books = ["581526", "20562717", "944652"]

# %%
# !head book_id_map.csv
# Out:
# book_id_csv,book_id
# 0,34684622
# 1,34536488
# 2,34017076
# 3,71730
# 4,30422361
# 5,33503613
# 6,33517540
# 7,34467031
# 8,6383669

# %%
# Create a dictionary, splitting the file at the comma into csv_id and book_id
csv_book_mapping = {}

with open("book_id_map.csv", "r") as f:
    while True:
        line =f.readline()
        if not line:
            break
        csv_id, book_id = line.strip().split(",") # .strip() removes any new line characters
        csv_book_mapping[csv_id] = book_id

# %%
len(csv_book_mapping)
# Out:
# 2360651

# %%
# First, find all of the users who like the same books
# Populate a set of users using the streaming fashion to reduce memory usage
overlap_users = set()

with open("goodreads_interactions.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",") # underscore means we don't care about the field, this will give us user_id, csv_id, and rating
        
        if user_id in overlap_users:
            continue
        
        try:
            rating = int(rating)
        except ValueError:
            continue
            
        book_id = csv_book_mapping[csv_id] # turn the csv_id into a book_id
        
        if book_id in liked_books and rating >= 4: # if the book in the row is one we like and the rating is 4 or 5, add that user to overlap users
            overlap_users.add(user_id) # this set will contain any user who read the same book and rated it highly

# %%
# Finding the books that those users read
# Create a list with recommended lines
rec_lines = []

with open("goodreads_interactions.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        if user_id in overlap_users:
            book_id = csv_book_mapping[csv_id]
            rec_lines.append([user_id, book_id, rating]) # Contains books that users who like the same books as us have read

# %%
import pandas as pd

# Create a DataFrame with the potential recommendations and pass in column names
recs = pd.DataFrame(rec_lines, columns=["user_id", "book_id", "rating"])

# Ensure book_id is a string
recs["book_id"] = recs["book_id"].astype(str)

# %%
recs
# Out:
#        user_id   book_id rating
# 0          286     48855      5
# 1          286   9418327      0
# 2          286     47281      3
# 3          286    114345      2
# 4          286    375013      5
# ...        ...       ...    ...
# 374096  873461  20562717      4
# 374097  873461   9531737      4
# 374098  873461  20150777      5
# 374099  873461   8167044      5
# 374100  873461  19385917      0
#
# [374101 rows x 3 columns]

# %%
# See which book_id occurs most in the df
top_recs = recs["book_id"].value_counts().head(10)

# Get the values of the index rather than the keys as book_ids is a dictionary with keys and values
top_recs = top_recs.index.values

# %%
# Look at the books_titles file we created in the search.ipynb file
books_titles = pd.read_json("books_titles.json")

# Ensure book_id is a string
books_titles["book_id"] = books_titles["book_id"].astype(str)

# %%
books_titles.head()
# Out:
#    book_id                                              title  ratings  \
# 0  1333909                                        Good Harbor       10
# 1  7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 2  6066819                               Best Friends Forever    51184
# 3   287140  Runic Astrology: Starcraft and Timekeeping in ...       15
# 4   287141                      The Aeneid for Boys and Girls       46
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/1333909.Go...
# 1  https://www.goodreads.com/book/show/7327624-th...
# 2  https://www.goodreads.com/book/show/6066819-be...
# 3  https://www.goodreads.com/book/show/287140.Run...
# 4  https://www.goodreads.com/book/show/287141.The...
#
#                                          cover_image  \
# 0  https://s.gr-assets.com/assets/nophoto/book/11...
# 1  https://images.gr-assets.com/books/1304100136m...
# 2  https://s.gr-assets.com/assets/nophoto/book/11...
# 3  https://images.gr-assets.com/books/1413219371m...
# 4  https://s.gr-assets.com/assets/nophoto/book/11...
#
#                                            mod_title
# 0                                        good harbor
# 1     the unschooled wizard sun wolf and starhawk 12
# 2                               best friends forever
# 3  runic astrology starcraft and timekeeping in t...
# 4                      the aeneid for boys and girls

# %%
# Use the isin method to find the book titles where the book_id is in the top recommendations
books_titles[books_titles["book_id"].isin(top_recs)]
# Out:
#           book_id                                              title  ratings  \
# 181196   20562717  The Name of the Wind (The Kingkiller Chronicle...    15824
# 203480    9531737  The Wise Man's Fear (The Kingkiller Chronicle,...    17766
# 386663    2767052            The Hunger Games (The Hunger Games, #1)  4899965
# 608482       5907                                         The Hobbit  2099680
# 838525       5470                                               1984  2023937
# 1077226      2657                              To Kill a Mockingbird  3255518
# 1196415         3  Harry Potter and the Sorcerer's Stone (Harry P...  4765497
# 1229158    136251  Harry Potter and the Deathly Hallows (Harry Po...  1784684
# 1316662     13496     A Game of Thrones (A Song of Ice and Fire, #1)  1359501
# 1354988     15881  Harry Potter and the Chamber of Secrets (Harry...  1821802
#
#                                                        url  \
# 181196   https://www.goodreads.com/book/show/20562717-t...
# 203480   https://www.goodreads.com/book/show/9531737-th...
# 386663   https://www.goodreads.com/book/show/2767052-th...
# 608482   https://www.goodreads.com/book/show/5907.The_H...
# 838525       https://www.goodreads.com/book/show/5470.1984
# 1077226  https://www.goodreads.com/book/show/2657.To_Ki...
# 1196415  https://www.goodreads.com/book/show/3.Harry_Po...
# 1229158  https://www.goodreads.com/book/show/136251.Har...
# 1316662  https://www.goodreads.com/book/show/13496.A_Ga...
# 1354988  https://www.goodreads.com/book/show/15881.Harr...
#
#                                                cover_image  \
# 181196   https://images.gr-assets.com/books/1470701050m...
# 203480   https://images.gr-assets.com/books/1327957823m...
# 386663   https://images.gr-assets.com/books/1447303603m...
# 608482   https://images.gr-assets.com/books/1372847500m...
# 838525   https://images.gr-assets.com/books/1348990566m...
# 1077226  https://images.gr-assets.com/books/1361975680m...
# 1196415  https://images.gr-assets.com/books/1474154022m...
# 1229158  https://images.gr-assets.com/books/1474171184m...
# 1316662  https://images.gr-assets.com/books/1436732693m...
# 1354988  https://images.gr-assets.com/books/1474169725m...
#
#                                                  mod_title
# 181196     the name of the wind the kingkiller chronicle 1
# 203480       the wise mans fear the kingkiller chronicle 2
# 386663                 the hunger games the hunger games 1
# 608482                                          the hobbit
# 838525                                                1984
# 1077226                              to kill a mockingbird
# 1196415  harry potter and the sorcerers stone harry pot...
# 1229158  harry potter and the deathly hallows harry pot...
# 1316662         a game of thrones a song of ice and fire 1
# 1354988  harry potter and the chamber of secrets harry ...

# %%
# Get value_counts() with how many times each book_id appears in the set
all_recs = recs["book_id"].value_counts()

# %%
# Convert to a df from a series
all_recs = all_recs.to_frame().reset_index()

# Rename columns
all_recs.columns = ["book_id", "book_count"]

# %%
all_recs.head()
# Out:
#     book_id  book_count
# 0  20562717         787
# 1         3         460
# 2   9531737         442
# 3   2767052         401
# 4      5907         373

# %%
# Merge all_recs with books_titles using inner meaning if the data doesn't exist in both, get rid of the row
all_recs = all_recs.merge(books_titles, how="inner", on="book_id")

# %%
# Create a score such that if a book is popular in our set but less popular in general on goodreads, it'll be more highly scored
all_recs["score"] = all_recs["book_count"] * (all_recs["book_count"] / all_recs["ratings"])

# %%
# Sort the top ten recommendations based upon score
all_recs.sort_values("score", ascending=False).head(10)
# Out:
#        book_id  book_count                                              title  \
# 0     20562717         787  The Name of the Wind (The Kingkiller Chronicle...
# 69    21032488         154      Doors of Stone (The Kingkiller Chronicle, #3)
# 2      9531737         442  The Wise Man's Fear (The Kingkiller Chronicle,...
# 2506  18243345          18                        Nightblood (Warbreaker, #2)
# 1041  29217027          34                    Iron Gold (Red Rising Saga, #4)
# 4294  15999003          12          Inherit the Night (Gentleman Bastard, #7)
# 5222  26860699          10        The Olympian Affair (The Cinder Spires, #2)
# 1191  23947089          31                      The Lost Metal (Mistborn, #7)
# 477   17250961          59           Oathbringer (The Stormlight Archive, #3)
# 861     581526          39                    In My Own Way: An Autobiography
#
#       ratings                                                url  \
# 0       15824  https://www.goodreads.com/book/show/20562717-t...
# 69       2059  https://www.goodreads.com/book/show/21032488-d...
# 2       17766  https://www.goodreads.com/book/show/9531737-th...
# 2506       66  https://www.goodreads.com/book/show/18243345-n...
# 1041      256  https://www.goodreads.com/book/show/29217027-i...
# 4294       36  https://www.goodreads.com/book/show/15999003-i...
# 5222       27  https://www.goodreads.com/book/show/26860699-t...
# 1191      305  https://www.goodreads.com/book/show/23947089-t...
# 477      1121  https://www.goodreads.com/book/show/17250961-o...
# 861       508  https://www.goodreads.com/book/show/581526.In_...
#
#                                             cover_image  \
# 0     https://images.gr-assets.com/books/1470701050m...
# 69    https://s.gr-assets.com/assets/nophoto/book/11...
# 2     https://images.gr-assets.com/books/1327957823m...
# 2506  https://s.gr-assets.com/assets/nophoto/book/11...
# 1041  https://images.gr-assets.com/books/1482474951m...
# 4294  https://s.gr-assets.com/assets/nophoto/book/11...
# 5222  https://s.gr-assets.com/assets/nophoto/book/11...
# 1191  https://s.gr-assets.com/assets/nophoto/book/11...
# 477   https://images.gr-assets.com/books/1500062685m...
# 861   https://s.gr-assets.com/assets/nophoto/book/11...
#
#                                             mod_title      score
# 0     the name of the wind the kingkiller chronicle 1  39.141115
# 69          doors of stone the kingkiller chronicle 3  11.518213
# 2       the wise mans fear the kingkiller chronicle 2  10.996510
# 2506                          nightblood warbreaker 2   4.909091
# 1041                      iron gold red rising saga 4   4.515625
# 4294            inherit the night gentleman bastard 7   4.000000
# 5222          the olympian affair the cinder spires 2   3.703704
# 1191                        the lost metal mistborn 7   3.150820
# 477              oathbringer the stormlight archive 3   3.105263
# 861                    in my own way an autobiography   2.994094

# %%
# Filter all recommendations for a book count greater than 200
all_recs[all_recs["book_count"] > 200].sort_values("score", ascending=False).head()
# Out:
#      book_id  book_count                                              title  \
# 0   20562717         787  The Name of the Wind (The Kingkiller Chronicle...
# 2    9531737         442  The Wise Man's Fear (The Kingkiller Chronicle,...
# 35     68428         213                    The Final Empire (Mistborn, #1)
# 27   9969571         233                                   Ready Player One
# 31      4407         223                  American Gods (American Gods, #1)
#
#     ratings                                                url  \
# 0     15824  https://www.goodreads.com/book/show/20562717-t...
# 2     17766  https://www.goodreads.com/book/show/9531737-th...
# 35   216149  https://www.goodreads.com/book/show/68428.The_...
# 27   376328  https://www.goodreads.com/book/show/9969571-re...
# 31   379668  https://www.goodreads.com/book/show/4407.Ameri...
#
#                                           cover_image  \
# 0   https://images.gr-assets.com/books/1470701050m...
# 2   https://images.gr-assets.com/books/1327957823m...
# 35  https://images.gr-assets.com/books/1480717416m...
# 27  https://images.gr-assets.com/books/1500930947m...
# 31  https://images.gr-assets.com/books/1258417001m...
#
#                                           mod_title      score
# 0   the name of the wind the kingkiller chronicle 1  39.141115
# 2     the wise mans fear the kingkiller chronicle 2  10.996510
# 35                      the final empire mistborn 1   0.209897
# 27                                 ready player one   0.144260
# 31                    american gods american gods 1   0.130980

# %%
# Only take the recommendations where book_count is greater than 200
popular_recs = all_recs[all_recs["book_count"] > 200].sort_values("score", ascending=False)

# %%
def make_clickable(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val, val)

def show_image(val):
    return '<a href="{}"><img src="{}" width=50></img></a>.'.format(val, val)

# Filter out popular books where book_id isin liked_books
popular_recs[~popular_recs["book_id"].isin(liked_books)].head(10).style.format({'url': make_clickable, 'cover_image': show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_ae148_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >book_id</th>
#       <th class="col_heading level0 col1" >book_count</th>
#       <th class="col_heading level0 col2" >title</th>
#       <th class="col_heading level0 col3" >ratings</th>
#       <th class="col_heading level0 col4" >url</th>
#       <th class="col_heading level0 col5" >cover_image</th>
#       <th class="col_heading level0 col6" >mod_title</th>
#       <th class="col_heading level0 col7" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae148_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_ae148_row0_col0" class="data row0 col0" >9531737</td>
#       <td id="T_ae148_row0_col1" class="data row0 col1" >442</td>
#       <td id="T_ae148_row0_col2" class="data row0 col2" >The Wise Man's Fear (The Kingkiller Chronicle, #2)</td>
#       <td id="T_ae148_row0_col3" class="data row0 col3" >17766</td>
#       <td id="T_ae148_row0_col4" class="data row0 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/9531737-the-wise-man-s-fear">Goodreads</a></td>
#       <td id="T_ae148_row0_col5" class="data row0 col5" ><a href="https://images.gr-assets.com/books/1327957823m/9531737.jpg"><img src="https://images.gr-assets.com/books/1327957823m/9531737.jpg" width=50></img></a>.</td>
#       <td id="T_ae148_row0_col6" class="data row0 col6" >the wise mans fear the kingkiller chronicle 2</td>
#       <td id="T_ae148_row0_col7" class="data row0 col7" >10.996510</td>
#     </tr>
#     <tr>
#       <th id="T_ae148_level0_row1" class="row_heading level0 row1" >35</th>
#       <td id="T_ae148_row1_col0" class="data row1 col0" >68428</td>
#       <td id="T_ae148_row1_col1" class="data row1 col1" >213</td>
#       <td id="T_ae148_row1_col2" class="data row1 col2" >The Final Empire (Mistborn, #1)</td>
#       <td id="T_ae148_row1_col3" class="data row1 col3" >216149</td>
#       <td id="T_ae148_row1_col4" class="data row1 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/68428.The_Final_Empire">Goodreads</a></td>
#       <td id="T_ae148_row1_col5" class="data row1 col5" ><a href="https://images.gr-assets.com/books/1480717416m/68428.jpg"><img src="https://images.gr-assets.com/books/1480717416m/68428.jpg" width=50></img></a>.</td>
#       <td id="T_ae148_row1_col6" class="data row1 col6" >the final empire mistborn 1</td>
#       <td id="T_ae148_row1_col7" class="data row1 col7" >0.209897</td>
#     </tr>
#     <tr>
#       <th id="T_ae148_level0_row2" class="row_heading level0 row2" >27</th>
#       <td id="T_ae148_row2_col0" class="data row2 col0" >9969571</td>
#       <td id="T_ae148_row2_col1" class="data row2 col1" >233</td>
#       <td id="T_ae148_row2_col2" class="data row2 col2" >Ready Player One</td>
#       <td id="T_ae148_row2_col3" class="data row2 col3" >376328</td>
#       <td id="T_ae148_row2_col4" class="data row2 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/9969571-ready-player-one">Goodreads</a></td>
#       <td id="T_ae148_row2_col5" class="data row2 col5" ><a href="https://images.gr-assets.com/books/1500930947m/9969571.jpg"><img src="https://images.gr-assets.com/books/1500930947m/9969571.jpg" width=50></img></a>.</td>
#       <td id="T_ae148_row2_col6" class="data row2 col6" >ready player one</td>
#       <td id="T_ae148_row2_col7" class="data row2 col7" >0.144260</td>
#     </tr>
#     <tr>
#       <th id="T_ae148_level0_row3" class="row_heading level0 row3" >31</th>
#       <td id="T_ae148_row3_col0" class="data row3 col0" >4407</td>
#       <td id="T_ae148_row3_col1" class="data row3 col1" >223</td>
#       <td id="T_ae148_row3_col2" class="data row3 col2" >American Gods (American Gods, #1)</td>
#       <td id="T_ae148_row3_col3" class="data row3 col3" >379668</td>
#       <td id="T_ae148_row3_col4" class="data row3 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/4407.American_Gods">Goodreads</a></td>
#       <td id="T_ae148_row3_col5" class="data row3 col5" ><a href="https://images.gr-assets.com/books/1258417001m/4407.jpg"><img src="https://images.gr-assets.com/books/1258417001m/4407.jpg" width=50></img></a>.</td>
#       <td id="T_ae148_row3_col6" class="data row3 col6" >american gods american gods 1</td>
#       <td id="T_ae148_row3_col7" class="data row3 col7" >0.130980</td>
#     </tr>
#     <tr>
#       <th id="T_ae148_level0_row4" class="row_heading level0 row4" >36</th>
#       <td id="T_ae148_row4_col0" class="data row4 col0" >10664113</td>
#       <td id="T_ae148_row4_col1" class="data row4 col1" >210</td>
#       <td id="T_ae148_row4_col2" class="data row4 col2" >A Dance with Dragons (A Song of Ice and Fire, #5)</td>
#       <td id="T_ae148_row4_col3" class="data row4 col3" >374315</td>
#       <td id="T_ae148_row4_col4" class="data row4 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/10664113-a-dance-with-dragons">Goodreads</a></td>
#       <td id="T_ae148_row4_col5" class="data row4 col5" ><a href="https://images.gr-assets.com/books/1327885335m/10664113.jpg"><img src="https://images.gr-assets.com/books/1327885335m/10664113.jpg" width=50></img></a>.</td>
#       <td id="T_ae148_row4_col6" class="data row4 col6" >a dance with dragons a song of ice and fire 5</td>
#       <td id="T_ae148_row4_col7" class="data row4 col7" >0.117815</td>
#     </tr>
#     <tr>
#       <th id="T_ae148_level0_row5" class="row_heading level0 row5" >14</th>
#       <td id="T_ae148_row5_col0" class="data row5 col0" >375802</td>
#       <td id="T_ae148_row5_col1" class="data row5 col1" >311</td>
#       <td id="T_ae148_row5_col2" class="data row5 col2" >Ender's Game (Ender's Saga, #1)</td>
#       <td id="T_ae148_row5_col3" class="data row5 col3" >829380</td>
#       <td id="T_ae148_row5_col4" class="data row5 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/375802.Ender_s_Game">Goodreads</a></td>
#       <td id="T_ae148_row5_col5" class="data row5 col5" ><a href="https://images.gr-assets.com/books/1408303130m/375802.jpg"><img src="https://images.gr-assets.com/books/1408303130m/375802.jpg" width=50></img></a>.</td>
#       <td id="T_ae148_row5_col6" class="data row5 col6" >enders game enders saga 1</td>
#       <td id="T_ae148_row5_col7" class="data row5 col7" >0.116618</td>
#     </tr>
#     <tr>
#       <th id="T_ae148_level0_row6" class="row_heading level0 row6" >23</th>
#       <td id="T_ae148_row6_col0" class="data row6 col0" >234225</td>
#       <td id="T_ae148_row6_col1" class="data row6 col1" >238</td>
#       <td id="T_ae148_row6_col2" class="data row6 col2" >Dune (Dune Chronicles #1)</td>
#       <td id="T_ae148_row6_col3" class="data row6 col3" >494553</td>
#       <td id="T_ae148_row6_col4" class="data row6 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/234225.Dune">Goodreads</a></td>
#       <td id="T_ae148_row6_col5" class="data row6 col5" ><a href="https://images.gr-assets.com/books/1434908555m/234225.jpg"><img src="https://images.gr-assets.com/books/1434908555m/234225.jpg" width=50></img></a>.</td>
#       <td id="T_ae148_row6_col6" class="data row6 col6" >dune dune chronicles 1</td>
#       <td id="T_ae148_row6_col7" class="data row6 col7" >0.114536</td>
#     </tr>
#     <tr>
#       <th id="T_ae148_level0_row7" class="row_heading level0 row7" >34</th>
#       <td id="T_ae148_row7_col0" class="data row7 col0" >13497</td>
#       <td id="T_ae148_row7_col1" class="data row7 col1" >213</td>
#       <td id="T_ae148_row7_col2" class="data row7 col2" >A Feast for Crows (A Song of Ice and Fire, #4)</td>
#       <td id="T_ae148_row7_col3" class="data row7 col3" >437398</td>
#       <td id="T_ae148_row7_col4" class="data row7 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/13497.A_Feast_for_Crows">Goodreads</a></td>
#       <td id="T_ae148_row7_col5" class="data row7 col5" ><a href="https://images.gr-assets.com/books/1429538615m/13497.jpg"><img src="https://images.gr-assets.com/books/1429538615m/13497.jpg" width=50></img></a>.</td>
#       <td id="T_ae148_row7_col6" class="data
